# %%
import os
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup

class RozetkaDescriptionParser:
    def __init__(self, category_url):
        # Init browser
        options = webdriver.ChromeOptions()
        options.add_argument('headless')
        options.add_argument('--lang=uk-UA')
        self.browser = webdriver.Chrome(options=options)

        self.category_url = category_url
        self.data_dir = data_dir
        self.page_count = 0
        self.product_hrefs_iter = iter([])
        self.total_dscr_count = 0
        self.page_dscr_count = 0

    def parse(self, num_dscr):
        i = 0
        while i < num_dscr:
            try:
                # Try to get the next product on current
                product_href = next(self.product_hrefs_iter)
                self.page_dscr_count += 1
            except StopIteration:
                # If no products left on current page, get a new one
                self.page_count += 1
                self.update_product_hrefs()
                product_href = next(self.product_hrefs_iter)
                self.page_dscr_count = 1

            # Extract description
            soup = self._browser_get_soup(product_href)
            try:
                dscr = self._extract_dscr_from_prod(soup)
                self.total_dscr_count += 1
                print(f'   Description for product {self.total_dscr_count} ({self.page_dscr_count} on page)')
                i += 1
                yield dscr
            except:                
                print(f'   Skipped product {self.total_dscr_count} {product_href} ({self.page_dscr_count} on page)')
    
    def update_product_hrefs(self):
        soup = self._browser_get_soup(self.category_url + f'page={self.page_count}/')
        print('Updated product page', self.page_count)
        self.product_hrefs_iter = iter([a['href'] for a in soup.select('a.goods-tile__heading')])
        
    def _browser_get_soup(self, query):
        self.browser.get(query)
        html = self.browser.page_source
        soup = BeautifulSoup(html, 'html.parser')
        return soup
    
    def _extract_dscr_from_prod(self, soup):
        prod_name = soup.select_one('.product__title').get_text(separator=' ').strip()
        
        prod_dscr_paras = soup.select('div.product-about__description p')
        if not prod_dscr_paras:
            prod_dscr_paras = soup.select('div.text.rich-content div.rz-sec_text')
        if not prod_dscr_paras:
            prod_dscr_paras = soup.select('div.text.rich-content div.rz-section__subtitle')
        if not prod_dscr_paras:
            assert False
        
        prod_dscr = [p.get_text(separator=' ').strip() for p in prod_dscr_paras]
        full_dscr = prod_name + '. ' + ' '.join(prod_dscr)
        return full_dscr

# %%
category_url = 'https://rozetka.com.ua/ua/tablets/c130309/'
data_dir = os.path.join('.', 'data', 'dscr_tablets')
parser = RozetkaDescriptionParser(category_url)

# %%
for dscr in parser.parse(400):
    with open(os.path.join(data_dir, str(parser.total_dscr_count) + '.txt'), 'w+', encoding='UTF-8') as file:
        file.write(dscr)
# Out:
# Updated product page 1
#    Description for product 1 (1 on page)
#    Description for product 2 (2 on page)
#    Description for product 3 (3 on page)
#    Description for product 4 (4 on page)
#    Description for product 5 (5 on page)
#    Description for product 6 (6 on page)
#    Description for product 7 (7 on page)
#    Description for product 8 (8 on page)
#    Description for product 9 (9 on page)
#    Description for product 10 (10 on page)
#    Description for product 11 (11 on page)
#    Description for product 12 (12 on page)
#    Description for product 13 (13 on page)
#    Description for product 14 (14 on page)
#    Description for product 15 (15 on page)
#    Description for product 16 (16 on page)
#    Description for product 17 (17 on page)
#    Description for product 18 (18 on page)
#    Description for product 19 (19 on page)
#    Description for product 20 (20 on page)
#    Description for product 21 (21 on page)
#    Description for product 22 (22 on page)
#    Description for product 23 (23 on page)
#    Description for product 24 (24 on page)
#    Description for product 25 (25 on page)
#    Description for product 26 (26 on page)
#    Description for product 27 (27 on page)
#    Description for product 28 (28 on page)
#    Description for product 29 (29 on page)
#    Description for product 30 (30 on page)
#    Description for product 31 (31 on page)
#    Description for product 32 (32 on page)
#    Description for product 33 (33 on page)
#    Description for product 34 (34 on page)
#    Description for product 35 (35 on page)
#    Description for product 36 (36 on page)
#    Description for product 37 (37 on page)
#    Description for product 38 (38 on page)
#    Description for product 39 (39 on page)
#    Description for product 40 (40 on page)
#    Description for product 41 (41 on page)
#    Description for product 42 (42 on page)
#    Description for product 43 (43 on page)
#    Description for product 44 (44 on page)
#    Description for product 45 (45 on page)
#    Description for product 46 (46 on page)
#    Description for product 47 (47 on page)
#    Description for product 48 (48 on page)
#    Description for product 49 (49 on page)
#    Description for product 50 (50 on page)
#    Description for product 51 (51 on page)
#    Description for product 52 (52 on page)
#    Description for product 53 (53 on page)
#    Description for product 54 (54 on page)
#    Description for product 55 (55 on page)
#    Description for product 56 (56 on page)
#    Description for product 57 (57 on page)
#    Description for product 58 (58 on page)
#    Description for product 59 (59 on page)
#    Description for product 60 (60 on page)
# Updated product page 2
#    Description for product 61 (1 on page)
#    Description for product 62 (2 on page)
#    Description for product 63 (3 on page)
#    Description for product 64 (4 on page)
#    Description for product 65 (5 on page)
#    Description for product 66 (6 on page)
#    Description for product 67 (7 on page)
#    Description for product 68 (8 on page)
#    Description for product 69 (9 on page)
#    Description for product 70 (10 on page)
#    Skipped product 70 https://rozetka.com.ua/ua/planshet-telefon-hoozo-mt116-black/g19794293/ (11 on page)
#    Description for product 71 (12 on page)
#    Skipped product 71 https://rozetka.com.ua/ua/244739443/p244739443/ (13 on page)
#    Description for product 72 (14 on page)
#    Description for product 73 (15 on page)
#    Description for product 74 (16 on page)
#    Description for product 75 (17 on page)
#    Description for product 76 (18 on page)
#    Description for product 77 (19 on page)
#    Description for product 78 (20 on page)
#    Description for product 79 (21 on page)
#    Skipped product 79 https://rozetka.com.ua/ua/244739449/p244739449/ (22 on page)
#    Skipped product 79 https://rozetka.com.ua/ua/242956135/p242956135/ (23 on page)
#    Description for product 80 (24 on page)
#    Description for product 81 (25 on page)
#    Skipped product 81 https://rozetka.com.ua/ua/29881969/g29881969/ (26 on page)
#    Description for product 82 (27 on page)
#    Description for product 83 (28 on page)
#    Description for product 84 (29 on page)
#    Skipped product 84 https://rozetka.com.ua/ua/planshet-telefon-hoozo-mt116-2gb-ram-black-chekhol-klaviatura/g19794391/ (30 on page)
#    Description for product 85 (31 on page)
#    Description for product 86 (32 on page)
#    Description for product 87 (33 on page)
#    Skipped product 87 https://rozetka.com.ua/ua/244739437/p244739437/ (34 on page)
#    Description for product 88 (35 on page)
#    Description for product 89 (36 on page)
#    Description for product 90 (37 on page)
#    Description for product 91 (38 on page)
#    Skipped product 91 https://rozetka.com.ua/ua/243134365/p243134365/ (39 on page)
#    Description for product 92 (40 on page)
#    Description for product 93 (41 on page)
#    Description for product 94 (42 on page)
#    Description for product 95 (43 on page)
#    Description for product 96 (44 on page)
#    Description for product 97 (45 on page)
#    Description for product 98 (46 on page)
#    Description for product 99 (47 on page)
#    Skipped product 99 https://rozetka.com.ua/ua/231654877/p231654877/ (48 on page)
#    Skipped product 99 https://rozetka.com.ua/ua/176376432/p176376432/ (49 on page)
#    Skipped product 99 https://rozetka.com.ua/ua/68845767/p68845767/ (50 on page)
#    Skipped product 99 https://rozetka.com.ua/ua/139487728/p139487728/ (51 on page)
#    Description for product 100 (52 on page)
#    Description for product 101 (53 on page)
#    Description for product 102 (54 on page)
#    Description for product 103 (55 on page)
#    Skipped product 103 https://rozetka.com.ua/ua/258179341/p258179341/ (56 on page)
#    Description for product 104 (57 on page)
#    Skipped product 104 https://rozetka.com.ua/ua/68845743/p68845743/ (58 on page)
#    Description for product 105 (59 on page)
#    Description for product 106 (60 on page)
# Updated product page 3
#    Description for product 107 (1 on page)
#    Description for product 108 (2 on page)
#    Skipped product 108 https://rozetka.com.ua/ua/258194561/p258194561/ (3 on page)
#    Skipped product 108 https://rozetka.com.ua/ua/139487812/p139487812/ (4 on page)
#    Description for product 109 (5 on page)
#    Skipped product 109 https://rozetka.com.ua/ua/219756589/p219756589/ (6 on page)
#    Description for product 110 (7 on page)
#    Skipped product 110 https://rozetka.com.ua/ua/planset---telefon-hoozo-x1001-full-hd-32gb-lte-cehol-knizka-karta-pamati-64gb/g21692875/ (8 on page)
#    Description for product 111 (9 on page)
#    Description for product 112 (10 on page)
#    Description for product 113 (11 on page)
#    Description for product 114 (12 on page)
#    Description for product 115 (13 on page)
#    Description for product 116 (14 on page)
#    Description for product 117 (15 on page)
#    Description for product 118 (16 on page)
#    Description for product 119 (17 on page)
#    Description for product 120 (18 on page)
#    Description for product 121 (19 on page)
#    Description for product 122 (20 on page)
#    Description for product 123 (21 on page)
#    Description for product 124 (22 on page)
#    Description for product 125 (23 on page)
#    Skipped product 125 https://rozetka.com.ua/ua/planshet---telefon-hoozo-mt232-gold-chekhol-klaviatura/g19789792/ (24 on page)
#    Description for product 126 (25 on page)
#    Description for product 127 (26 on page)
#    Description for product 128 (27 on page)
#    Description for product 129 (28 on page)
#    Description for product 130 (29 on page)
#    Description for product 131 (30 on page)
#    Description for product 132 (31 on page)
#    Description for product 133 (32 on page)
#    Skipped product 133 https://rozetka.com.ua/ua/257645291/p257645291/ (33 on page)
#    Description for product 134 (34 on page)
#    Description for product 135 (35 on page)
#    Skipped product 135 https://rozetka.com.ua/ua/planshet-hoozo-x1001-32gb-lte/g12550994/ (36 on page)
#    Description for product 136 (37 on page)
#    Description for product 137 (38 on page)
#    Description for product 138 (39 on page)
#    Description for product 139 (40 on page)
#    Description for product 140 (41 on page)
#    Description for product 141 (42 on page)
#    Description for product 142 (43 on page)
#    Description for product 143 (44 on page)
#    Skipped product 143 https://rozetka.com.ua/ua/231953917/p231953917/ (45 on page)
#    Skipped product 143 https://rozetka.com.ua/ua/planshet---telefon-hoozo-mt232-gold-chekhol-klaviatura-karta-pamyati-64gb/g19789890/ (46 on page)
#    Description for product 144 (47 on page)
#    Description for product 145 (48 on page)
#    Description for product 146 (49 on page)
#    Skipped product 146 https://rozetka.com.ua/ua/planshet-evromedia-play-pad-3g-2goo/g15575202/ (50 on page)
#    Skipped product 146 https://rozetka.com.ua/ua/139487875/p139487875/ (51 on page)
#    Description for product 147 (52 on page)
#    Description for product 148 (53 on page)
#    Description for product 149 (54 on page)
#    Description for product 150 (55 on page)
#    Description for product 151 (56 on page)
#    Description for product 152 (57 on page)
#    Description for product 153 (58 on page)
#    Description for product 154 (59 on page)
#    Skipped product 154 https://rozetka.com.ua/ua/planshet-telefon-hoozo-mt116-2gb-ram-black-chekhol-klaviatura-karta-pamyati-32gb/g19794433/ (60 on page)
# Updated product page 4
#    Skipped product 154 https://rozetka.com.ua/ua/184799315/p184799315/ (1 on page)
#    Description for product 155 (2 on page)
#    Description for product 156 (3 on page)
#    Description for product 157 (4 on page)
#    Description for product 158 (5 on page)
#    Description for product 159 (6 on page)
#    Skipped product 159 https://rozetka.com.ua/ua/245241721/p245241721/ (7 on page)
#    Description for product 160 (8 on page)
#    Description for product 161 (9 on page)
#    Description for product 162 (10 on page)
#    Description for product 163 (11 on page)
#    Description for product 164 (12 on page)
#    Description for product 165 (13 on page)
#    Skipped product 165 https://rozetka.com.ua/ua/260231501/p260231501/ (14 on page)
#    Description for product 166 (15 on page)
#    Skipped product 166 https://rozetka.com.ua/ua/176350189/p176350189/ (16 on page)
#    Description for product 167 (17 on page)
#    Skipped product 167 https://rozetka.com.ua/ua/230516647/p230516647/ (18 on page)
#    Description for product 168 (19 on page)
#    Description for product 169 (20 on page)
#    Description for product 170 (21 on page)
#    Skipped product 170 https://rozetka.com.ua/ua/259424816/p259424816/ (22 on page)
#    Skipped product 170 https://rozetka.com.ua/ua/planset---telefon-hoozo-x1001-full-hd-32gb-lte-cehol-klaviatura/g21692847/ (23 on page)
#    Skipped product 170 https://rozetka.com.ua/ua/planset---telefon-hoozo-x1001-full-hd-32gb-lte-cehol-klaviatura-karta-pamati-64gb/g21692861/ (24 on page)
#    Description for product 171 (25 on page)
#    Description for product 172 (26 on page)
#    Description for product 173 (27 on page)
#    Description for product 174 (28 on page)
#    Description for product 175 (29 on page)
#    Description for product 176 (30 on page)
#    Description for product 177 (31 on page)
#    Description for product 178 (32 on page)
#    Skipped product 178 https://rozetka.com.ua/ua/146844357/p146844357/ (33 on page)
#    Description for product 179 (34 on page)
#    Description for product 180 (35 on page)
#    Description for product 181 (36 on page)
#    Description for product 182 (37 on page)
#    Description for product 183 (38 on page)
#    Description for product 184 (39 on page)
#    Description for product 185 (40 on page)
#    Description for product 186 (41 on page)
#    Description for product 187 (42 on page)
#    Description for product 188 (43 on page)
#    Description for product 189 (44 on page)
#    Description for product 190 (45 on page)
#    Skipped product 190 https://rozetka.com.ua/ua/221898553/p221898553/ (46 on page)
#    Description for product 191 (47 on page)
#    Description for product 192 (48 on page)
#    Description for product 193 (49 on page)
#    Description for product 194 (50 on page)
#    Description for product 195 (51 on page)
#    Description for product 196 (52 on page)
#    Description for product 197 (53 on page)
#    Description for product 198 (54 on page)
#    Description for product 302 (53 on page)
#    Description for product 303 (54 on page)
#    Skipped product 303 https://rozetka.com.ua/ua/242956141/p242956141/ (55 on page)
#    Description for product 304 (56 on page)
#    Description for product 305 (57 on page)
#    Description for product 306 (58 on page)
#    Description for product 307 (59 on page)
#    Description for product 308 (60 on page)
# Updated product page 8
#    Skipped product 308 https://rozetka.com.ua/ua/175258357/p175258357/ (1 on page)
#    Skipped product 308 https://rozetka.com.ua/ua/245133409/p245133409/ (2 on page)
#    Description for product 309 (3 on page)
#    Skipped product 309 https://rozetka.com.ua/ua/30888101/g30888101/ (4 on page)
#    Description for product 310 (5 on page)
#    Skipped product 310 https://rozetka.com.ua/ua/259429796/p259429796/ (6 on page)
#    Skipped product 310 https://rozetka.com.ua/ua/254202121/p254202121/ (7 on page)
#    Description for product 311 (8 on page)
#    Description for product 312 (9 on page)
#    Skipped product 312 https://rozetka.com.ua/ua/219757963/p219757963/ (10 on page)
#    Skipped product 312 https://rozetka.com.ua/ua/239553505/p239553505/ (11 on page)
#    Description for product 313 (12 on page)
#    Skipped product 313 https://rozetka.com.ua/ua/139505179/p139505179/ (13 on page)
#    Description for product 314 (14 on page)
#    Description for product 315 (15 on page)
#    Description for product 316 (16 on page)
#    Description for product 317 (17 on page)
#    Description for product 318 (18 on page)
#    Description for product 319 (19 on page)
#    Skipped product 319 https://rozetka.com.ua/ua/231273157/p231273157/ (20 on page)
#    Description for product 320 (21 on page)
#    Description for product 321 (22 on page)
#    Description for product 322 (23 on page)
#    Skipped product 322 https://rozetka.com.ua/ua/68845725/p68845725/ (24 on page)
#    Description for product 323 (25 on page)
#    Skipped product 323 https://rozetka.com.ua/ua/219757507/p219757507/ (26 on page)
#    Skipped product 323 https://rozetka.com.ua/ua/planshet-hoozo-mt232-silver-chekhol-knizhka-karta-pamyati-32gb/g19790023/ (27 on page)
#    Description for product 324 (28 on page)
#    Skipped product 324 https://rozetka.com.ua/ua/219758407/p219758407/ (29 on page)
#    Description for product 325 (30 on page)
#    Description for product 326 (31 on page)
#    Description for product 327 (32 on page)
#    Skipped product 327 https://rozetka.com.ua/ua/139488022/p139488022/ (33 on page)
#    Description for product 328 (34 on page)
#    Skipped product 328 https://rozetka.com.ua/ua/233535199/p233535199/ (35 on page)
#    Description for product 329 (36 on page)
#    Description for product 330 (37 on page)
#    Skipped product 330 https://rozetka.com.ua/ua/239758735/p239758735/ (38 on page)
#    Description for product 331 (39 on page)
#    Description for product 332 (40 on page)
#    Description for product 333 (41 on page)
#    Description for product 334 (42 on page)
#    Description for product 335 (43 on page)
#    Description for product 336 (44 on page)
#    Description for product 337 (45 on page)
#    Description for product 338 (46 on page)
#    Description for product 339 (47 on page)
#    Description for product 340 (48 on page)
#    Description for product 341 (49 on page)
#    Description for product 342 (50 on page)
#    Description for product 343 (51 on page)
#    Description for product 344 (52 on page)
#    Description for product 345 (53 on page)
#    Description for product 346 (54 on page)
#    Description for product 347 (55 on page)
#    Description for product 348 (56 on page)
#    Description for product 349 (57 on page)
#    Skipped product 349 https://rozetka.com.ua/ua/112336448/p112336448/ (58 on page)
#    Skipped product 349 https://rozetka.com.ua/ua/240051265/p240051265/ (59 on page)
#    Description for product 350 (60 on page)
# Updated product page 9
#    Description for product 351 (1 on page)
#    Description for product 352 (2 on page)
#    Description for product 353 (3 on page)
#    Description for product 354 (4 on page)
#    Description for product 355 (5 on page)
#    Description for product 356 (6 on page)
#    Skipped product 356 https://rozetka.com.ua/ua/219756763/p219756763/ (7 on page)
#    Skipped product 356 https://rozetka.com.ua/ua/185242814/p185242814/ (8 on page)
#    Description for product 357 (9 on page)
#    Description for product 358 (10 on page)
#    Skipped product 358 https://rozetka.com.ua/ua/219757441/p219757441/ (11 on page)
#    Description for product 359 (12 on page)
#    Description for product 360 (13 on page)
#    Description for product 361 (14 on page)
#    Skipped product 361 https://rozetka.com.ua/ua/planshet-telefon-hoozo-mt116-2gb-ram-black-chekhol-knizhka-karta-pamyati-32gb/g19794482/ (15 on page)
#    Description for product 362 (16 on page)
#    Description for product 363 (17 on page)
#    Description for product 364 (18 on page)
#    Description for product 365 (19 on page)
#    Description for product 366 (20 on page)
#    Description for product 367 (21 on page)
#    Description for product 368 (22 on page)
#    Description for product 369 (23 on page)
#    Description for product 370 (24 on page)
#    Skipped product 370 https://rozetka.com.ua/ua/219758449/p219758449/ (25 on page)
#    Skipped product 370 https://rozetka.com.ua/ua/254202091/p254202091/ (26 on page)
#    Description for product 371 (27 on page)
#    Description for product 372 (28 on page)
#    Description for product 373 (29 on page)
#    Description for product 374 (30 on page)
#    Description for product 375 (31 on page)
#    Skipped product 375 https://rozetka.com.ua/ua/197896159/p197896159/ (32 on page)
#    Description for product 376 (33 on page)
#    Description for product 377 (34 on page)
#    Description for product 378 (35 on page)
#    Description for product 379 (36 on page)
#    Description for product 380 (37 on page)
#    Description for product 381 (38 on page)
#    Description for product 382 (39 on page)
#    Description for product 383 (40 on page)
#    Description for product 384 (41 on page)
#    Description for product 385 (42 on page)
#    Description for product 386 (43 on page)
#    Skipped product 386 https://rozetka.com.ua/ua/233535409/p233535409/ (44 on page)
#    Description for product 387 (45 on page)
#    Skipped product 387 https://rozetka.com.ua/ua/233535211/p233535211/ (46 on page)
#    Description for product 388 (47 on page)
#    Description for product 389 (48 on page)
#    Description for product 390 (49 on page)
#    Description for product 391 (50 on page)
#    Skipped product 391 https://rozetka.com.ua/ua/219757111/p219757111/ (51 on page)
#    Description for product 392 (52 on page)
#    Description for product 393 (53 on page)
#    Description for product 394 (54 on page)
#    Description for product 395 (55 on page)
#    Description for product 396 (56 on page)
#    Description for product 397 (57 on page)
#    Description for product 398 (58 on page)
#    Description for product 399 (59 on page)
#    Description for product 400 (60 on page)

# %%
# options = webdriver.ChromeOptions()
# # options.add_argument('headless')
# browser = webdriver.Chrome(options=options)
# browser.set_window_size(1920, 1080)
# browser.get('https://rozetka.com.ua/ua/oppo_a91_128gb_blue/p208181857/')
# html = browser.page_source
# soup = BeautifulSoup(html, 'html.parser')

# soup.select_one('.product__title').get_text(separator=' ').strip()
# soup.select_one('div.text.rich-content div.rz-sec_text').get_text(separator=' ')
